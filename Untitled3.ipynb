# %%
import requests
#r = requests.get('https://api.github.com/user', auth=('user', 'pass'))

# %%
response = requests.get("https://sportsop-soccer-sports-open-data-v1.p.rapidapi.com/v1/leagues/Premier-League/seasons",
  headers={
    "X-RapidAPI-Host": "sportsop-soccer-sports-open-data-v1.p.rapidapi.com",
    "X-RapidAPI-Key": "05e330ab07mshc78f2cb5280d470p14869ajsnd0b57fa9da68"
  }
)

# %%
response
# Out:
# <Response [403]>

# %%
import pandas as pd
import numpy as np
import re

# %%
managers = pd.read_csv('manager.csv')
managers#.loc[0]['Name']
# Out:
#                                                   Name  Nat.  \
# 0    <span data-sort-value="Graham, George">George ...   NaN
# 1    <span data-sort-value="Houston, Stewart">Stewa...   NaN
# 2     <span data-sort-value="Rioch, Bruce">Bruce Rioch   NaN
# 3    <span data-sort-value="Houston, Stewart">Stewa...   NaN
# 4           <span data-sort-value="Rice, Pat">Pat Rice   NaN
# 5    <span data-sort-value="Wenger, Arsene">Arsène ...   NaN
# 6       <span data-sort-value="Emery, Unai">Unai Emery   NaN
# 7    <span data-sort-value="Atkinson, Ron">Ron Atki...   NaN
# 8    <span data-sort-value="Little, Brian">Brian Li...   NaN
# 9    <span data-sort-value="Gregory, John">John Gre...   NaN
# 10    <span data-sort-value="Deehan, John">John Deehan   NaN
# 11    <span data-sort-value="Gray, Stuart">Stuart Gray   NaN
# 12   <span data-sort-value="Taylor, Graham">Graham ...   NaN
# 13   <span data-sort-value="O'Leary, David">David O...   NaN
# ...

# %%
stripped = re.sub('<[^<]+?>', '', text)
